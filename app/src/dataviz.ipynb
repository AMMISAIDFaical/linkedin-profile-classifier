# %%
import pandas as pd

df = pd.read_csv('/workspaces/linkedin-profile-classifier/TestData-Classified.csv')
df
# Out:
#    First Name                     Profile Type  \
# 0    Benjamin  Board Member / Private Investor
# 1        Hani                    Ex-Consulting
# 2       Régis  Board Member / Private Investor
# 3       Marco                 Big Tech C-level
# 4    Frédéric  Board Member / Private Investor
# 5        Alex                 Big Tech C-level
# 6        Rémi                    Ex-Consulting
# 7    Matthieu              Exited Entrepreneur
# 8        Lars                 Big Tech C-level
# 9   Guillaume  Board Member / Private Investor
# 10      Julia                 Big Tech C-level
# 11      Marie              Exited Entrepreneur
# 12      Sunil  Board Member / Private Investor
# 13     Simone                 Big Tech C-level
#
#                                          LinkedIn URL  \
# 0                      https://linkedin.com/in/benmah
# 1    https://www.linkedin.com/in/hani-baramki-1406335
# 2           https://www.linkedin.com/in/regiscazenave
# ...

# %%
for i in range(len(df)):
    print(df.loc[i, 'First Name'],"-------", df.loc[i, 'Profile Type'],"-------", df.loc[i, 'Reasoning'])
    print()
# Out:
# Benjamin ------- Board Member / Private Investor ------- Dr. Benjamin Mah has over 30 years of professional experience and his current association is with SparksBM Investment, indicating involvement in investments. This aligns well with the profile type of a Board Member / Private Investor rather than operational or executive roles.
#
# Hani ------- Ex-Consulting ------- Hani Baramki has recent experience at PwC Middle East, which is a consulting firm. His profile highlights expertise in strategy formulation, change management, corporate turnarounds, and business development, indicating a strong consulting background. There is no explicit indication of him being a top mentor, serial business angel, or big tech C-level executive, nor clear evidence of exited entrepreneur or board member status.
#
# ...
